# %%
import pandas as pd 
import numpy as np

# %%
from google.colab import drive

drive.mount('/content/drive')

import pandas as pd

tt = pd.read_csv('/content/drive/MyDrive/twitter_training.csv')
# Out:
# Mounted at /content/drive

# %%
tt=pd.read_csv('twitter_training.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2900/3961641374.py in <cell line: 0>()
# ----> 1 tt=pd.read_csv('twitter_training.csv')
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...

# %%
tt.head(5)
# Out:
#    2401  Borderlands  Positive  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#   im getting on borderlands and i will murder you all ,
# 0  I am coming to the borders and I will kill you...
# 1  im getting on borderlands and i will kill you ...
# 2  im coming on borderlands and i will murder you...
# 3  im getting on borderlands 2 and i will murder ...
# 4  im getting into borderlands and i can murder y...

# %%
tt.isnull().sum()
# Out:
# 2401                                                       0
# Borderlands                                                0
# Positive                                                   0
# im getting on borderlands and i will murder you all ,    686
# dtype: int64

# %%
tt.shape
# Out:
# (74681, 4)

# %%
tt['Positive'].value_counts()
# Out:
# Positive
# Negative      22542
# Positive      20831
# Neutral       18318
# Irrelevant    12990
# Name: count, dtype: int64

# %%
tt.duplicated().sum()
# Out:
# np.int64(2700)

# %%
tt=tt.dropna()

# %%
tt.isnull().sum()
# Out:
# 2401                                                     0
# Borderlands                                              0
# Positive                                                 0
# im getting on borderlands and i will murder you all ,    0
# dtype: int64

# %%
tt.shape
# Out:
# (73995, 4)

# %%
tt.drop_duplicates(inplace=True)

# %%
tt.duplicated().sum()
# Out:
# np.int64(0)

# %%
tt=tt.drop(columns=['2401','Borderlands'])

# %%
tt
# Out:
#        Positive im getting on borderlands and i will murder you all ,
# 0      Positive  I am coming to the borders and I will kill you...
# 1      Positive  im getting on borderlands and i will kill you ...
# 2      Positive  im coming on borderlands and i will murder you...
# 3      Positive  im getting on borderlands 2 and i will murder ...
# 4      Positive  im getting into borderlands and i can murder y...
# ...         ...                                                ...
# 74676  Positive  Just realized that the Windows partition of my...
# 74677  Positive  Just realized that my Mac window partition is ...
# 74678  Positive  Just realized the windows partition of my Mac ...
# 74679  Positive  Just realized between the windows partition of...
# 74680  Positive  Just like the windows partition of my Mac is l...
#
# [71655 rows x 2 columns]

# %%
tt=tt.rename(columns={'Positive':'Sentiment','im getting on borderlands and i will murder you all ,':'Tweets'})

# %%
tt
# Out:
#       Sentiment                                             Tweets
# 0      Positive  I am coming to the borders and I will kill you...
# 1      Positive  im getting on borderlands and i will kill you ...
# 2      Positive  im coming on borderlands and i will murder you...
# 3      Positive  im getting on borderlands 2 and i will murder ...
# 4      Positive  im getting into borderlands and i can murder y...
# ...         ...                                                ...
# 74676  Positive  Just realized that the Windows partition of my...
# 74677  Positive  Just realized that my Mac window partition is ...
# 74678  Positive  Just realized the windows partition of my Mac ...
# 74679  Positive  Just realized between the windows partition of...
# 74680  Positive  Just like the windows partition of my Mac is l...
#
# [71655 rows x 2 columns]

# %%
tt=tt[(tt['Sentiment']=='Negative')|(tt['Sentiment']=='Positive')|(tt['Sentiment']=='Neutral')]

# %%
tt['Sentiment'].value_counts()
# Out:
# Sentiment
# Negative    21698
# Positive    19712
# Neutral     17708
# Name: count, dtype: int64

# %%
tt.shape
# Out:
# (59118, 2)

# %% [markdown]
# ## Feature Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
tt['Sentiment']=le.fit_transform(tt['Sentiment'])
# Out:
# /tmp/ipykernel_2900/2973148363.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tt['Sentiment']=le.fit_transform(tt['Sentiment'])

# %%
tt
# Out:
#        Sentiment                                             Tweets
# 0              2  I am coming to the borders and I will kill you...
# 1              2  im getting on borderlands and i will kill you ...
# 2              2  im coming on borderlands and i will murder you...
# 3              2  im getting on borderlands 2 and i will murder ...
# 4              2  im getting into borderlands and i can murder y...
# ...          ...                                                ...
# 74676          2  Just realized that the Windows partition of my...
# 74677          2  Just realized that my Mac window partition is ...
# 74678          2  Just realized the windows partition of my Mac ...
# 74679          2  Just realized between the windows partition of...
# 74680          2  Just like the windows partition of my Mac is l...
#
# [59118 rows x 2 columns]

# %% [markdown]
# ## Tokenizers

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer=Tokenizer(oov_token='Nothing')

# %%
tokenizer.fit_on_texts(tt['Tweets'])

# %%
tt
# Out:
#        Sentiment                                             Tweets
# 0              2  I am coming to the borders and I will kill you...
# 1              2  im getting on borderlands and i will kill you ...
# 2              2  im coming on borderlands and i will murder you...
# 3              2  im getting on borderlands 2 and i will murder ...
# 4              2  im getting into borderlands and i can murder y...
# ...          ...                                                ...
# 74676          2  Just realized that the Windows partition of my...
# 74677          2  Just realized that my Mac window partition is ...
# 74678          2  Just realized the windows partition of my Mac ...
# 74679          2  Just realized between the windows partition of...
# 74680          2  Just like the windows partition of my Mac is l...
#
# [59118 rows x 2 columns]

# %%
tokenizer.word_index
# Out:
# {'Nothing': 1,
#  'the': 2,
#  'i': 3,
#  'to': 4,
#  'and': 5,
#  'a': 6,
#  'of': 7,
#  'is': 8,
#  'in': 9,
#  'for': 10,
#  'it': 11,
#  'this': 12,
#  'my': 13,
#  'on': 14,
#  'you': 15,
#  'that': 16,
#  'com': 17,
#  'game': 18,
#  'with': 19,
#  'so': 20,
#  'be': 21,
#  'me': 22,
#  'have': 23,
#  'just': 24,
#  'but': 25,
#  'not': 26,
#  'are': 27,
#  'all': 28,
#  'was': 29,
#  'at': 30,
#  'like': 31,
#  '2': 32,
#  'out': 33,
#  'from': 34,
#  'your': 35,
#  'now': 36,
#  'get': 37,
#  'pic': 38,
#  'twitter': 39,
#  'as': 40,
#  't': 41,
#  'we': 42,
#  'play': 43,
#  'johnson': 44,
#  'they': 45,
#  'one': 46,
#  'can': 47,
#  'do': 48,
#  'if': 49,
#  'new': 50,
#  'good': 51,
#  'no': 52,
#  'about': 53,
#  'an': 54,
#  'has': 55,
#  'will': 56,
#  'really': 57,
#  'when': 58,
#  'more': 59,
#  'up': 60,
#  "i'm": 61,
#  'what': 62,
#  'time': 63,
#  'love': 64,
#  'unk': 65,
#  '3': 66,
#  'or': 67,
#  'how': 68,
#  'why': 69,
#  'by': 70,
#  'some': 71,
# ...

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('i', 24421),
#              ('am', 1517),
#              ('coming', 403),
#              ('to', 23771),
#              ('the', 36098),
#              ('borders', 11),
#              ('and', 21712),
#              ('will', 2684),
#              ('kill', 348),
#              ('you', 9359),
#              ('all', 4492),
#              ('im', 547),
#              ('getting', 1046),
#              ('on', 9756),
#              ('borderlands', 1412),
#              ('murder', 67),
#              ('2', 3716),
#              ('me', 5527),
#              ('into', 947),
#              ('can', 2904),
#              ('so', 6410),
#              ('spent', 179),
#              ('a', 19236),
#              ('few', 467),
#              ('hours', 481),
#              ('making', 527),
#              ('something', 752),
#              ('for', 12494),
#              ('fun', 1329),
#              ('if', 2857),
#              ("don't", 1337),
#              ('know', 1391),
# ...

# %%
tt
# Out:
#        Sentiment                                             Tweets
# 0              2  I am coming to the borders and I will kill you...
# 1              2  im getting on borderlands and i will kill you ...
# 2              2  im coming on borderlands and i will murder you...
# 3              2  im getting on borderlands 2 and i will murder ...
# 4              2  im getting into borderlands and i can murder y...
# ...          ...                                                ...
# 74676          2  Just realized that the Windows partition of my...
# 74677          2  Just realized that my Mac window partition is ...
# 74678          2  Just realized the windows partition of my Mac ...
# 74679          2  Just realized between the windows partition of...
# 74680          2  Just like the windows partition of my Mac is l...
#
# [59118 rows x 2 columns]

# %%
sequences=tokenizer.texts_to_sequences(tt['Tweets'])

# %%
sequences
# Out:
# [[3, 114, 400, 4, 2, 6290, 5, 3, 56, 455, 15, 28],
#  [314, 171, 14, 121, 5, 3, 56, 455, 15, 28],
#  [314, 400, 14, 121, 5, 3, 56, 1737, 15, 28],
#  [314, 171, 14, 121, 32, 5, 3, 56, 1737, 15, 22, 28],
#  [314, 171, 191, 121, 5, 3, 47, 1737, 15, 28],
#  [20,
#   3,
#   798,
#   6,
#   361,
#   347,
#   324,
#   240,
#   10,
#   133,
#   49,
#   15,
#   130,
#   125,
#   3,
#   114,
#   6,
#   496,
#   121,
#   629,
#   5,
#   3924,
#   8,
#   46,
#   7,
#   13,
#   328,
#   749,
#   20,
#   3,
#   739,
#   4,
#   123,
#   491,
#   6,
#   5328,
#   10,
#   13,
#   282,
#   145,
#   8,
#   2,
#   762,
#   2053,
#   5577,
#   2,
#   8859,
#   3,
#   213,
#   425,
#   38,
#   39,
#   17,
#   15636],
#  [20,
#   3,
#   798,
#   6,
#   1012,
#   7,
#   347,
#   308,
#   240,
#   10,
#   133,
#   49,
#   15,
#   130,
#   125,
#   16,
#   61,
#   6,
#   496,
#   121,
#   629,
#   5,
#   3924,
#   8,
#   46,
#   7,
#   13,
#   328,
#   749,
#   3,
#   739,
#   4,
#   123,
#   6,
#   5328,
# ...

# %%
from keras.utils import pad_sequences

# %%
sequences=pad_sequences(sequences,padding='pre')

# %%
sequences
# Out:
# array([[   0,    0,    0, ...,  455,   15,   28],
#        [   0,    0,    0, ...,  455,   15,   28],
#        [   0,    0,    0, ..., 1737,   15,   28],
#        ...,
#        [   0,    0,    0, ...,  154, 1028, 2541],
#        [   0,    0,    0, ...,   79,   41, 2541],
#        [   0,    0,    0, ...,    3, 1028, 2541]], dtype=int32)

# %%
len(sequences[0])
# Out:
# 166

# %%
len(sequences[1])
# Out:
# 166

# %%
from tensorflow.keras.layers import SimpleRNN,Dense,Input,Embedding

# %%
from tensorflow.keras.models import Sequential

# %%
x=sequences
y=tt['Sentiment']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (47294, 166)

# %%
model=Sequential()
model.add(SimpleRNN(32,input_shape=(166,1),return_sequences=False))
model.add(Dense(3,activation='softmax'))
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,187 (4.64 KB)
#  Trainable params: 1,187 (4.64 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',metrics=['accuracy'],loss='sparse_categorical_crossentropy')

# %%
model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test),batch_size=128)
# Out:
# Epoch 1/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.3636 - loss: 1.1005 - val_accuracy: 0.3664 - val_loss: 1.0892
# Epoch 2/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3617 - loss: 1.0944 - val_accuracy: 0.3723 - val_loss: 1.0933
# Epoch 3/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.3643 - loss: 1.0957 - val_accuracy: 0.3701 - val_loss: 1.0925
# Epoch 4/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3627 - loss: 1.0964 - val_accuracy: 0.3753 - val_loss: 1.0944
# Epoch 5/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3665 - loss: 1.0956 - val_accuracy: 0.3706 - val_loss: 1.0929
# Epoch 6/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.3625 - loss: 1.0964 - val_accuracy: 0.3691 - val_loss: 1.0930
# Epoch 7/10
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.3637 - loss: 1.0952 - val_accuracy: 0.3709 - val_loss: 1.0925
# Epoch 8/10
# ...

# %%
vocab_size=len(tokenizer.word_index)+1

# %%
vocab_size
# Out:
# 29230

# %%
model2=Sequential()
model2.add(Input(shape=(166,)))
model2.add(Embedding(input_dim=vocab_size,output_dim=128))
model2.add(Dense(3,activation='softmax'))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 166, 128)       │     3,741,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 166, 3)         │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,741,827 (14.27 MB)
#  Trainable params: 3,741,827 (14.27 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_final=Sequential([Embedding(input_dim=vocab_size,output_dim=128,input_length=166,mask_zero=True),
SimpleRNN(32),Dense(3,activation='softmax')])
# Out:
# /usr/local/lib/python3.13/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model_final.compile(optimizer='adam',metrics=['accuracy'],loss='sparse_categorical_crossentropy')

# %%
model_final.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model_final.fit(x_train,y_train,epochs=100,validation_data=(x_test,y_test),batch_size=128)
# Out:
# Epoch 1/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.7285 - loss: 0.6375 - val_accuracy: 0.8669 - val_loss: 0.3539
# Epoch 2/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9343 - loss: 0.1792 - val_accuracy: 0.8975 - val_loss: 0.2691
# Epoch 3/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9631 - loss: 0.0946 - val_accuracy: 0.9034 - val_loss: 0.2609
# Epoch 4/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9720 - loss: 0.0670 - val_accuracy: 0.9061 - val_loss: 0.2697
# Epoch 5/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9748 - loss: 0.0566 - val_accuracy: 0.9034 - val_loss: 0.2951
# Epoch 6/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9760 - loss: 0.0525 - val_accuracy: 0.9021 - val_loss: 0.3111
# Epoch 7/100
# 370/370 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.9770 - loss: 0.0482 - val_accuracy: 0.8988 - val_loss: 0.3309
# Epoch 8/100
# ...

# %%
import pickle

# %%
with open('tokenizer.pkl','wb') as file:
    pickle.dump(tokenizer,file)

# %%
model_final.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'model.h5', 'drive', 'tokenizer.pkl', 'sample_data']

# %%
from google.colab import files

files.download('model.h5')
files.download('tokenizer.pkl')

# %%
import os

print(os.getcwd())
print(os.path.exists("model.h5"))
print(os.path.exists("tokenizer.pkl"))
# Out:
# /content
# True
# True

# %%
from google.colab import files

files.download('/content/model.h5')
files.download('/content/tokenizer.pkl')

# %%
import zipfile

with zipfile.ZipFile('rnn_model_files.zip', 'w') as zipf:
    zipf.write('model.h5')
    zipf.write('tokenizer.pkl')

print("Created:", os.path.abspath('rnn_model_files.zip'))
# Out:
# Created: /content/rnn_model_files.zip

# %%
from google.colab import files
files.download('rnn_model_files.zip')

# %%
import os
print("Working directory:", os.getcwd())
print("Files:")
for f in os.listdir():
    print(f)
# Out:
# Working directory: /content
# Files:
# .config
# model.h5
# drive
# tokenizer.pkl
# rnn_model_files.zip
# sample_data

# %%
import shutil
import os

drive_folder = '/content/drive/MyDrive/rnndeploy'

os.makedirs(drive_folder, exist_ok=True)

shutil.copy('/content/model.h5', drive_folder)
shutil.copy('/content/tokenizer.pkl', drive_folder)

print("Files copied successfully!")
print(os.listdir(drive_folder))
# Out:
# Files copied successfully!
# ['model.h5', 'tokenizer.pkl']
